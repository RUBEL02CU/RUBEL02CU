# %% [markdown]
# <a href="https://colab.research.google.com/github/RUBEL02CU/RUBEL02CU/blob/main/INSE6220_PROJECT_RUBEL_KAR_40237535.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install PyCaret**
#
# PyCaret is an open-source, low-code machine learning library in Python designed to make the end-to-end machine learning process easier and faster for both beginners and experienced data scientists. It offers a variety of tools and functions for data preparation, model training, model selection, and deployment.

# %%
# install slim version (default)
# !pip3 install pycaret==3.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pycaret==3.0.0 in /usr/local/lib/python3.10/dist-packages (3.0.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.13.5)
# Requirement already satisfied: sktime>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.17.2)
# Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (7.7.1)
# Requirement already satisfied: numba>=0.55.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.56.4)
# Requirement already satisfied: numpy<1.25,>=1.21 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.22.4)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (3.0.3)
# Requirement already satisfied: category-encoders>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.6.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (3.2.0)
# Requirement already satisfied: schemdraw>=0.14 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.16)
# Requirement already satisfied: pandas<1.6.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.2.0)
# Requirement already satisfied: scikit-plot>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.3.7)
# Requirement already satisfied: markupsafe>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.1.2)
# Requirement already satisfied: kaleido>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.2.1)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.0.3)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (7.34.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (5.8.0)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (5.13.1)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.8.3.2)
# Requirement already satisfied: tbats>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.1.3)
# Requirement already satisfied: jinja2>=1.2 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (3.1.2)
# Requirement already satisfied: pyod>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.0.9)
# Requirement already satisfied: yellowbrick>=1.4 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.5)
# Requirement already satisfied: scipy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (1.2.2)
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (5.9.5)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (3.7.1)
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (4.65.0)
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (3.3.5)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.27.1)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (0.10.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.2.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (6.6.0)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycaret==3.0.0) (2.1.0)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category-encoders>=2.4.0->pycaret==3.0.0) (0.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation>=2.1.0->pycaret==3.0.0) (23.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn>=0.8.1->pycaret==3.0.0) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.12.0->pycaret==3.0.0) (3.15.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (4.4.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (3.0.38)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (5.7.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.5.0->pycaret==3.0.0) (2.14.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (3.0.7)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (5.5.6)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (3.6.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->pycaret==3.0.0) (0.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from lightgbm>=3.0.0->pycaret==3.0.0) (0.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->pycaret==3.0.0) (1.0.7)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=4.2.0->pycaret==3.0.0) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=4.2.0->pycaret==3.0.0) (4.3.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/dist-packages (from nbformat>=4.2.0->pycaret==3.0.0) (5.3.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.55.0->pycaret==3.0.0) (0.39.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0,>=1.3.0->pycaret==3.0.0) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->pycaret==3.0.0) (8.2.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from plotly-resampler>=0.8.3.1->pycaret==3.0.0) (3.8.11)
# Requirement already satisfied: jupyter-dash>=0.4.2 in /usr/local/lib/python3.10/dist-packages (from plotly-resampler>=0.8.3.1->pycaret==3.0.0) (0.4.2)
# Requirement already satisfied: trace-updater>=0.0.8 in /usr/local/lib/python3.10/dist-packages (from plotly-resampler>=0.8.3.1->pycaret==3.0.0) (0.0.9.1)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.9.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret==3.0.0) (0.29.34)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret==3.0.0) (1.26.15)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pyod>=1.0.8->pycaret==3.0.0) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->pycaret==3.0.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->pycaret==3.0.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->pycaret==3.0.0) (3.4)
# Requirement already satisfied: deprecated>=1.2.13 in /usr/local/lib/python3.10/dist-packages (from sktime>=0.16.1->pycaret==3.0.0) (1.2.13)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.2.4)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.13->sktime>=0.16.1->pycaret==3.0.0) (1.14.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret==3.0.0) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret==3.0.0) (6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.5.0->pycaret==3.0.0) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.0.0) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.0.0) (23.1.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (1.5.6)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (1.3.4)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.10/dist-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (1.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.5.0->pycaret==3.0.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret==3.0.0) (0.2.6)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (6.4.8)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core->nbformat>=4.2.0->pycaret==3.0.0) (3.3.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (8.1.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.3.0)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret==3.0.0) (2.1.2)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.16.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (21.2.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.8.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (4.11.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.2.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.7.4)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.2.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret==3.0.0) (2.21)

# %%
from pycaret.utils import version
version()
# Out:
# '3.0.0'

# %% [markdown]
# ## **Principal Component Analysis**
#
# PCA stands for Principal Component Analysis, and it is a widely used technique in data analysis and machine learning for reducing the dimensionality of large datasets. The basic idea behind PCA is to transform a set of high-dimensional variables into a smaller set of uncorrelated variables called principal components, while retaining as much of the original variance as possible.

# %% [markdown]
# **Import Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
import pandas as pd
plt.rcParams['figure.figsize'] = (7,5)

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
print("Pandas version: ", pd.__version__)
print("Seaborn version: ", sns.__version__)
# Out:
# Pandas version:  1.5.3
# Seaborn version:  0.12.2

# %% [markdown]
# **Dataset**
#
# The dataset contains information on the age, cardiovascular health, and BMI of individuals. The cardiovascular health measures include systolic and diastolic blood pressure, cholesterol levels, and a binary indicator for heart disease. The dataset could be used to explore the relationships between these variables and to develop predictive models for cardiovascular disease.
#
#
# Attribute Information:
#
# To construct the data, 5 parameters of health were measured:
# 1. Age,
# 2. BMI,
# 3. Systolic BP,
# 4. Diastolic BP,
# 5. Cholesterol,
#
# All of these parameters were real-valued continuous.

# %% [markdown]
# **Read the dataset**
#
# **pd.read_csv** is a function in the pandas library in Python that is used to read a CSV (Comma Separated Values) file and convert it into a pandas DataFrame.

# %%
#read cvs file into dataframe
df = pd.read_csv('https://raw.githubusercontent.com/RUBEL02CU/RUBEL02CU/main/Heart2.csv')
df.head(25)
# Out:
#     Age  BMI  Systolic BP  Diastolic BP  Cholesterol  Heart Disease
# 0    50   23          118            70          220              0
# 1    52   27          128            78          250              1
# 2    31   22          110            70          200              0
# 3    35   21          105            60          180              0
# 4    48   24          122            76          240              0
# 5    57   29          140            88          280              1
# 6    43   23          122            72          230              0
# 7    55   26          130            84          260              1
# 8    36   22          118            64          210              0
# 9    39   24          126            80          200              0
# 10   53   25          134            82          270              1
# 11   41   23          120            70          190              0
# 12   44   27          132            76          230              1
# 13   47   25          122            80          210              0
# 14   34   21          112            68          170              0
# 15   56   28          134            84          250              1
# 16   49   25          130            78          200              0
# 17   53   24          128            78          230              1
# 18   37   22          116            72          190              0
# 19   39   24          118            70          200              0
# 20   46   27          130            78          220              1
# 21   48   27          134            82          240              1
# 22   57   30          140            88          280              1
# 23   51   28          128            82          230              1
# 24   56   30          142            88          260              1

# %%
# Convert integer data types to float data types
df = df.astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            249 non-null    float64
#  1   BMI            249 non-null    float64
#  2   Systolic BP    249 non-null    float64
#  3   Diastolic BP   249 non-null    float64
#  4   Cholesterol    249 non-null    float64
#  5   Heart Disease  249 non-null    float64
# dtypes: float64(6)
# memory usage: 11.8 KB

# %%
print("Number of duplicated rows is: ", df.duplicated().sum())
# Out:
# Number of duplicated rows is:  0

# %%
print("Number of rows with NaNs is: ", df.isna().any(axis=1).sum())
# Out:
# Number of rows with NaNs is:  0

# %% [markdown]
# **Exploratory Data Analysis**

# %% [markdown]
# **sns.pairplot** is a function in the seaborn library in Python that is used to plot pairwise relationships between multiple variables in a dataset. The resulting plot is a grid of scatterplots, with each variable plotted against every other variable.

# %%
sns.pairplot(df, hue='Heart Disease')
plt.show()

# %%
y =df['Heart Disease']
y.value_counts().plot(kind='pie')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Data Matrix**

# %%
X = df.drop(columns=['Heart Disease'])
X.head(10)
# Out:
#     Age   BMI  Systolic BP  Diastolic BP  Cholesterol
# 0  50.0  23.0        118.0          70.0        220.0
# 1  52.0  27.0        128.0          78.0        250.0
# 2  31.0  22.0        110.0          70.0        200.0
# 3  35.0  21.0        105.0          60.0        180.0
# 4  48.0  24.0        122.0          76.0        240.0
# 5  57.0  29.0        140.0          88.0        280.0
# 6  43.0  23.0        122.0          72.0        230.0
# 7  55.0  26.0        130.0          84.0        260.0
# 8  36.0  22.0        118.0          64.0        210.0
# 9  39.0  24.0        126.0          80.0        200.0

# %%
X.describe().transpose()
# Out:
#               count        mean        std    min    25%    50%    75%    max
# Age           249.0   44.574297   8.939509   23.0   38.0   45.0   52.0   67.0
# BMI           249.0   25.630522   2.805530   20.0   23.0   26.0   28.0   33.0
# Systolic BP   249.0  124.702811   9.637797  104.0  118.0  124.0  132.0  150.0
# Diastolic BP  249.0   77.883534   6.161673   60.0   74.0   78.0   82.0   92.0
# Cholesterol   249.0  209.269076  32.203672   20.0  187.0  210.0  230.0  280.0

# %% [markdown]
# **Standardize the Data**

# %%
Xs = StandardScaler().fit_transform(X)
Xcols = X.columns
X = pd.DataFrame(Xs)
X.columns = Xcols
X.head(10)
# Out:
#         Age       BMI  Systolic BP  Diastolic BP  Cholesterol
# 0  0.608158 -0.939509    -0.696872     -1.282024     0.333892
# 1  0.832334  0.489118     0.342799      0.018940     1.267339
# 2 -1.521519 -1.296666    -1.528609     -1.282024    -0.288406
# 3 -1.073166 -1.653822    -2.048445     -2.908228    -0.910704
# 4  0.383981 -0.582352    -0.281004     -0.306301     0.956190
# 5  1.392776  1.203432     1.590405      1.645144     2.200786
# 6 -0.176460 -0.939509    -0.281004     -0.956783     0.645041
# 7  1.168599  0.131962     0.550734      0.994662     1.578488
# 8 -0.961078 -1.296666    -0.696872     -2.257747     0.022743
# 9 -0.624813 -0.582352     0.134865      0.344181    -0.288406

# %%
X.describe().transpose()
# Out:
#               count          mean       std       min       25%       50%  \
# Age           249.0  1.997510e-16  1.002014 -2.418226 -0.736902  0.047716
# BMI           249.0  3.709661e-16  1.002014 -2.010979 -0.939509  0.131962
# Systolic BP   249.0 -6.991284e-16  1.002014 -2.152412 -0.696872 -0.073069
# Diastolic BP  249.0 -6.277888e-16  1.002014 -2.908228 -0.631542  0.018940
# Cholesterol   249.0 -2.853585e-16  1.002014 -5.889089 -0.692900  0.022743
#
#                    75%       max
# Age           0.832334  2.513658
# BMI           0.846275  2.632059
# Systolic BP   0.758668  2.630076
# Diastolic BP  0.669422  2.295626
# Cholesterol   0.645041  2.200786

# %% [markdown]
# **Observations and variables**

# %%
observations = list(df.index)
variables = list(df.columns)

# %% [markdown]
# **Box and Whisker Plots**

# %%
ax = plt.figure()
ax = sns.boxplot(data=X, orient="v", palette="Set2")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %%
# Use swarmplot() or stripplot to show the datapoints on top of the boxes:
#plt. figure()
ax = plt.figure()    
ax = sns.boxplot(data=X, orient="v", palette="Set2")
ax = sns.stripplot(data=X, color=".25") 
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %% [markdown]
# **Correlation Matrix**

# %%
ax = sns.heatmap(X.corr(), cmap='RdYlGn_r', linewidths=0.5, annot=True, cbar=False, square=True)
plt.yticks(rotation=0)
ax.tick_params(labelbottom=False,labeltop=True)
ax.set_xticklabels(ax.get_xticklabels(),rotation=0);

#X.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
#sns.clustermap(X.corr(), annot=True, fmt='.2f')

# %% [markdown]
# ##**Applying PCA**

# %%
pca = PCA()
Z = pca.fit_transform(X)

idx_no = np.where(y == 0)
idx_yes = np.where(y == 1)

plt.figure()
plt.scatter(Z[idx_no, 0], Z[idx_no, 1], c='r', label='No')
plt.scatter(Z[idx_yes, 0], Z[idx_yes, 1], c='g', label='Yes')
plt.legend()
plt.xlabel('$Z_1$')
plt.ylabel('$Z_2$')
plt.show()

# %% [markdown]
# **Eigenvectors**

# %%
A = pca.components_.T 

plt.scatter(A[:,0],A[:,1],c='r')
plt.xlabel('$A_1$')
plt.ylabel('$A_2$')
for label, x, y in zip(variables, A[:, 0], A[:, 1]):
  plt.annotate(label, xy=(x, y), xytext=(-2, 2), textcoords='offset points', ha='right', va='bottom')

# %%
plt.scatter(A[:, 0],A[:, 1], marker='o', c=A[:, 2], s=A[:, 3]*500, cmap=plt.get_cmap('Spectral'))
plt.xlabel('$A_1$')
plt.ylabel('$A_2$')
for label, x, y in zip(variables,A[:, 0],A[:, 1]):
  plt.annotate(label,xy=(x, y), xytext=(-20, 20),
      textcoords='offset points', ha='right', va='bottom',
      bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
      arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))

# %% [markdown]
# **Scree plot**

# %%
#Eigenvalues
Lambda = pca.explained_variance_ 

#Scree plot
x = np.arange(len(Lambda)) + 1
plt.plot(x,Lambda/sum(Lambda), 'ro-', lw=3)
plt.xticks(x, [""+str(i) for i in x], rotation=0)
plt.xlabel('Number of components')
plt.ylabel('Explained variance')
# Out:
# Text(0, 0.5, 'Explained variance')

# %% [markdown]
# **Explained Variance**

# %%
ell = pca.explained_variance_ratio_
ind = np.arange(len(ell))
plt.bar(ind, ell, align='center', alpha=0.5)
plt.plot(np.cumsum(ell))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %% [markdown]
# **Biplot**

# %%
# 0,1 denote PC1 and PC2; change values for other PCs
A1 = A[:,0] 
A2 = A[:,1]
Z1 = Z[:,0] 
Z2 = Z[:,1]

plt.figure()
plt.xlabel('$Z_1$')
plt.ylabel('$Z_2$')
for i in range(len(A1)):
    # arrows project features as vectors onto PC axes
    plt.arrow(0, 0, A1[i]*max(Z1), A2[i]*max(Z2), color='k', width=0.0005, head_width=0.0025)
    plt.text(A1[i]*max(Z1)*1.2, A2[i]*max(Z2)*1.2,variables[i], color='k')

idx_no = np.where(y == 0)
idx_yes = np.where(y == 1)

plt.scatter(Z[idx_no,0], Z[idx_no,1], c='r', label='No')
plt.scatter(Z[idx_yes,0], Z[idx_yes,1], c='g', label='Yes')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ##**Using PCA Library**

# %%
# !pip3 install pca
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pca in /usr/local/lib/python3.10/dist-packages (2.0.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from pca) (0.13.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pca) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pca) (2.27.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pca) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pca) (1.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pca) (1.5.3)
# Requirement already satisfied: scatterd>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from pca) (1.3.1)
# Requirement already satisfied: colourmap>=1.1.11 in /usr/local/lib/python3.10/dist-packages (from pca) (1.1.11)
# Requirement already satisfied: adjusttext in /usr/local/lib/python3.10/dist-packages (from pca) (0.8)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pca) (1.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pca) (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from scatterd>=1.3.1->pca) (0.12.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (4.39.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pca) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pca) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pca) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pca) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->pca) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pca) (1.26.15)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pca) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pca) (1.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels->pca) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels->pca) (1.16.0)

# %%
from pca import pca
# Initialize and keep all PCs
model = pca()
# Fit transform
out = model.fit_transform(X)
# Out:
# [pca] >Extracting column labels from dataframe.
# [pca] >Extracting row labels from dataframe.
# [pca] >The PCA reduction is performed to capture [95.0%] explained variance using the [5] columns of the input data.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Number of components is [3] that covers the [95.00%] explained variance.
# [pca] >The PCA reduction is performed on the [5] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[3]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[3]

# %% [markdown]
# **Principal Components**

# %%
out['PC']
# Out:
#           PC1       PC2       PC3
# 0   -0.944893 -1.558426  0.276845
# 1    1.282829 -0.916048 -0.204909
# 2   -2.669492 -0.428500 -0.797500
# 3   -3.894868 -1.201132  0.079939
# 4    0.028572 -1.186625 -0.373475
# ..        ...       ...       ...
# 244 -3.929720  0.067722 -0.089817
# 245 -1.583895  0.104531  0.311504
# 246  3.555109  0.584633  0.559186
# 247 -2.659142  0.143850  0.083106
# 248  4.078868  0.581591  0.355125
#
# [249 rows x 3 columns]

# %% [markdown]
# **Scatter plot**

# %%
model.scatter(label=True, legend=False)
# Out:
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# (<Figure size 2500x1500 with 1 Axes>,
#  <Axes: title={'center': '3 Principal Components explain [98.88%] of the variance'}, xlabel='PC1 (83.6% expl.var)', ylabel='PC2 (8.61% expl.var)'>)

# %% [markdown]
# **Eigenvectors**

# %%
A = out['loadings'].T

# %%
sns.scatterplot(data=A, x="PC1", y="PC2")
plt.xlabel('$A_1$')
plt.ylabel('$A_2$')
for i in range(A.shape[0]):
 plt.text(x=A.PC1[i]+0.02,y=A.PC2[i]+0.02, s=variables[i],
          fontdict=dict(color='red',size=10),
          bbox=dict(facecolor='yellow',alpha=0.5))

# %% [markdown]
# **Scree Plot**

# %%
VR = out['variance_ratio']
x = np.arange(len(VR)) + 1
plt.plot(x, VR, 'ro-', lw=3)
plt.xticks(x, [""+str(i) for i in x], rotation=0)
plt.xlabel('Number of components')
plt.ylabel('Explained variance') 
plt.show()

# %% [markdown]
# **Explained Variance Plot**

# %%
model.plot();

# %% [markdown]
# **Biplot**
#
# A biplot is a graphical representation of multivariate data that displays both observations and variables simultaneously in a single plot. Each observation is represented as a point in a two-dimensional plot, while the variables are represented as arrows or vectors that point in the direction of the greatest variation in the data. The length of the vector indicates the magnitude of the variable, while the angle between two vectors reflects their correlation.

# %%
model.biplot(label=False, legend=False)
# Out:
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# [pca] >Plot PC1 vs PC2 with loadings.
# (<Figure size 2500x1500 with 1 Axes>,
#  <Axes: title={'center': '3 Principal Components explain [98.88%] of the variance'}, xlabel='PC1 (83.6% expl.var)', ylabel='PC2 (8.61% expl.var)'>)

# %%
cova = np.cov(X.transpose())
covaMatrix = pd.DataFrame(cova)
covaMatrix.head(15)
# Out:
#           0         1         2         3         4
# 0  1.004032  0.747850  0.759803  0.728133  0.781810
# 1  0.747850  1.004032  0.916584  0.899385  0.704314
# 2  0.759803  0.916584  1.004032  0.941511  0.772220
# 3  0.728133  0.899385  0.941511  1.004032  0.719627
# 4  0.781810  0.704314  0.772220  0.719627  1.004032

# %%
pcss = PCA()
pcss.fit_transform(X)
A = pcss.components_.T 
Lambda = pcss.explained_variance_

# %%
print(f'Eigenvectors:\n{A}')
print(f'Eigenvalues:\n{Lambda}')
# Out:
# Eigenvectors:
# [[ 0.42645877 -0.52499249  0.72376774  0.13520513  0.01989068]
#  [ 0.45678263  0.36625541  0.14651548 -0.77595214 -0.18340692]
#  [ 0.46969448  0.277607   -0.13339571  0.19212929  0.80474429]
#  [ 0.45916633  0.39090862 -0.078401    0.57049017 -0.55204255]
#  [ 0.42194303 -0.60030381 -0.65631726 -0.13132081 -0.11662724]]
# Eigenvalues:
# [4.19940173 0.43232763 0.22756138 0.10473036 0.05614019]

# %%
# Top features in signifacnt PCs
out['topfeat']
# Out:
#     PC       feature   loading  type
# 0  PC1   Systolic BP  0.469694  best
# 1  PC2   Cholesterol -0.600304  best
# 2  PC3           Age  0.723768  best
# 3  PC1           BMI  0.456783  weak
# 4  PC1  Diastolic BP  0.459166  weak

# %%
A = out['loadings'].T
print(A)
# Out:
#                    PC1       PC2       PC3
# Age           0.426459 -0.524992  0.723768
# BMI           0.456783  0.366255  0.146515
# Systolic BP   0.469694  0.277607 -0.133396
# Diastolic BP  0.459166  0.390909 -0.078401
# Cholesterol   0.421943 -0.600304 -0.656317

# %% [markdown]
# #**Multiclass Classification with PyCaret**
#
# Multiclass classification is a supervised machine learning technique where the goal is to classify instances into one of three or more classes. (Classifying instances into one of two classes is called Binary Classification).

# %% [markdown]
# **Using PyCaret**
#
# PyCaret uses interactive plotting ability. In order to render interactive plots in Google Colab, run the below line of code in your colab notebook. The enable_colab() function in PyCaret is used to install and configure all the necessary dependencies to use PyCaret in Google Colab.

# %% [markdown]
# **Data Splitting**
#
# In order to demonstrate the predict_model() function on unseen data, a sample of 21 observations has been withheld from the original dataset to be used for predictions. This should not be confused with a train/test split as this particular split is performed to simulate a real life scenario. Another way to think about this is that these 21 records were not available at the time when the machine learning experiment was performed.

# %%
data = df.sample(frac=0.9, random_state=786)
data_unseen = df.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (224, 6)
# Unseen Data For Predictions: (25, 6)

# %% [markdown]
# **Setting up the Environment in PyCaret**
#
# The **setup()** function initializes the environment in pycaret and creates the transformation pipeline to prepare the data for modeling and deployment. setup() must be called before executing any other function in pycaret. It takes two mandatory parameters: a pandas dataframe and the name of the target column. All other parameters are optional and are used to customize the pre-processing pipeline.
#
# When setup() is executed, PyCaret's inference algorithm will automatically infer the data types for all features based on certain properties. The data type should be inferred correctly but this is not always the case. To account for this, PyCaret displays a table containing the features and their inferred data types after setup() is executed. If all of the data types are correctly identified enter can be pressed to continue or quit can be typed to end the expriment. Ensuring that the data types are correct is of fundamental importance in PyCaret as it automatically performs a few pre-processing tasks which are imperative to any machine learning experiment. These tasks are performed differently for each data type which means it is very important for them to be correctly configured.

# %%
from pycaret.classification import *
clf = setup(data=data, target='Heart Disease', train_size=0.7, session_id=123)
# Out:
# <style type="text/css">
# #T_3ebfc_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3ebfc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ebfc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3ebfc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ebfc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ebfc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3ebfc_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3ebfc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3ebfc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3ebfc_row1_col1" class="data row1 col1" >Heart Disease</td>
#     </tr>
#     <tr>
#       <th id="T_3ebfc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3ebfc_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3ebfc_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_3ebfc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3ebfc_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_3ebfc_row3_col1" class="data row3 col1" >(224, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_3ebfc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3ebfc_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_3ebfc_row4_col1" class="data row4 col1" >(224, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_3ebfc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3ebfc_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_3ebfc_row5_col1" class="data row5 col1" >(156, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_3ebfc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3ebfc_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_3ebfc_row6_col1" class="data row6 col1" >(68, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_3ebfc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3ebfc_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_3ebfc_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_3ebfc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3ebfc_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_3ebfc_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3ebfc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3ebfc_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_3ebfc_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_
#   text-align: left;
# }
# #T_0fcec_row0_col1, #T_0fcec_row0_col2, #T_0fcec_row1_col1, #T_0fcec_row1_col5, #T_0fcec_row1_col6, #T_0fcec_row1_col7, #T_0fcec_row2_col2, #T_0fcec_row2_col3, #T_0fcec_row2_col5, #T_0fcec_row3_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0fcec_row0_col8, #T_0fcec_row1_col8, #T_0fcec_row2_col8, #T_0fcec_row3_col8, #T_0fcec_row4_col8, #T_0fcec_row5_col8, #T_0fcec_row6_col8, #T_0fcec_row7_col8, #T_0fcec_row8_col8, #T_0fcec_row9_col8, #T_0fcec_row10_col8, #T_0fcec_row11_col8, #T_0fcec_row12_col8, #T_0fcec_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0fcec_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0fcec" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fcec_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0fcec_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0fcec_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0fcec_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0fcec_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0fcec_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0fcec_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0fcec_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_0fcec_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fcec_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_0fcec_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_0fcec_row0_col1" class="data row0 col1" >0.9742</td>
#       <td id="T_0fcec_row0_col2" class="data row0 col2" >0.9980</td>
#       <td id="T_0fcec_row0_col3" class="data row0 col3" >0.9433</td>
#       <td id="T_0fcec_row0_col4" class="data row0 col4" >0.9800</td>
#       <td id="T_0fcec_row0_col5" class="data row0 col5" >0.9598</td>
#       <td id="T_0fcec_row0_col6" class="data row0 col6" >0.9408</td>
#       <td id="T_0fcec_row0_col7" class="data row0 col7" >0.9427</td>
#       <td id="T_0fcec_row0_col8" class="data row0 col8" >0.1750</td>
#     </tr>
#     <tr>
#       <th id="T_0fcec_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_0fcec_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_0fcec_row1_col1" class="data row1 col1" >0.9742</td>
#       <td id="T_0fcec_row1_col2" class="data row1 col2" >0.9963</td>
#       <td id="T_0fcec_row1_col3" class="data row1 col3" >0.9467</td>
#       <td id="T_0fcec_row1_col4" class="data row1 col4" >0.9800</td>
#       <td id="T_0fcec_row1_col5" class="data row1 col5" >0.9618</td>
#       <td id="T_0fcec_row1_col6" class="data row1 col6" >0.9424</td>
#       <td id="T_0fcec_row1_col7" class="data row1 col7" >0.9441</td>
#       <td id="T_0fcec_row1_col8" class="data row1 col8" >0.2970</td>
#     </tr>
#     <tr>
#       <th id="T_0fcec_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_0fcec_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_0fcec_row2_col1" class="data row2 col1" >0.9738</td>
#       <td id="T_0fcec_row2_col2" class="data row2 col2" >0.9980</td>
#       <td id="T_0fcec_row2_col3" class="data row2 col3" >0.9633</td>
#       <td id="T_0fcec_row2_col4" class="data row2 col4" >0.9633</td>
#       <td id="T_0fcec_row2_col5" class="data row2 col5" >0.9618</td>
#       <td id="T_0fcec_row2_col6" class="data row2 col6" >0.9419</td>
#       <td id="T_0fcec_row2_col7" class="data row2 col7" >0.9436</td>
#       <td id="T_0fcec_row2_col8" class="data row2 col8" >0.0740</td>
#     </tr>
#     <tr>
#       <th id="T_0fcec_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_0fcec_row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#       <td id="T
row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_9215f_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_9215f_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_9215f_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_9215f_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_9215f_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9215f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9215f_row10_col0" class="data row10 col0" >0.9742</td>
#       <td id="T_9215f_row10_col1" class="data row10 col1" >0.9980</td>
#       <td id="T_9215f_row10_col2" class="data row10 col2" >0.9433</td>
#       <td id="T_9215f_row10_col3" class="data row10 col3" >0.9800</td>
#       <td id="T_9215f_row10_col4" class="data row10 col4" >0.9598</td>
#       <td id="T_9215f_row10_col5" class="data row10 col5" >0.9408</td>
#       <td id="T_9215f_row10_col6" class="data row10 col6" >0.9427</td>
#     </tr>
#     <tr>
#       <th id="T_9215f_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9215f_row11_col0" class="data row11 col0" >0.0435</td>
#       <td id="T_9215f_row11_col1" class="data row11 col1" >0.0060</td>
#       <td id="T_9215f_row11_col2" class="data row11 col2" >0.0870</td>
#       <td id="T_9215f_row11_col3" class="data row11 col3" >0.0600</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
#trained model object is stored in the variable 'rf'. 
rf
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=123, verbose=0, warm_start=False)

# %% [markdown]
# **Tune a Model:** How to automatically tune the hyper-parameters of a multiclass model. When a model is created using the create_model() function it uses the default hyperparameters. In order to tune hyperparameters, the tune_model() function is used. The tune_model() function is a random grid search of hyperparameters over a pre-defined search space. By default, it is set to optimize Accuracy but this can be changed using optimize parameter. This function automatically tunes the hyperparameters of a model on a pre-defined search space and scores it using stratified cross validation. The output prints a score grid that shows Accuracy, AUC, Recall, Precision, F1 and Kappa by fold.

# %% [markdown]
# **Tune Random Forest Classifier Model**

# %%
tuned_rf = tune_model(rf)
# Out:
# <style type="text/css">
# #T_34baf_row10_col0, #T_34baf_row10_col1, #T_34baf_row10_col2, #T_34baf_row10_col3, #T_34baf_row10_col4, #T_34baf_row10_col5, #T_34baf_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_34baf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34baf_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_34baf_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_34baf_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_34baf_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_34baf_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_34baf_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_34baf_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34baf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34baf_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_34baf_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_34baf_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_34baf_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_34baf_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_34baf_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_34baf_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_34baf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34baf_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_34baf_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_34baf_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_34baf_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_34baf_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_34baf_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_34baf_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_34baf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34baf_row2_col0" class="data row2 col0" >0.9375</td>
#       <td id="T_34baf_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_34baf_row2_col2" class="data row2 col2" >0.8333</td>
#       <td id="T_34baf_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_34baf_row2_col4" class="data row2 col4" >0.9091</td>
#       <td id="T_34baf_row2_col5" class="data row2 col5" >0.8621</td>
#       <td id="T_34baf_row2_col6" class="data row2 col6" >0.8704</td>
#     </tr>
#     <tr>
#       <th id="T_34baf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34baf_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_34baf_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_34baf_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_34baf_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_34baf_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_34baf_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_34baf_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_34baf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34baf_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_34baf_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_34baf_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_34baf_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_34baf_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_34baf_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_34baf_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_34baf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_34baf_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_34baf_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_34baf_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_34baf_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_34baf_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_34baf_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_34baf_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_34baf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_34baf_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_34baf_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_34baf_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_34baf_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_34baf_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_34baf_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_34baf_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_34baf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_34baf_row7_col0" class="data row7 col0" >0.9333</td>
#       <td id="T_34baf_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_34baf_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_34baf_row7_col3" class="data row7 col3" >0.8333</td>
#       <td id="T_34baf_row7_col4" class="data row7 col4" >0.9091</td>
#       <td id="T_34baf_row7_col5" class="data row7 col5" >0.8571</td>
#       <td id="T_34baf_row7_col6" class="data row7 col6" >0.8660</td>
#     </tr>
#     <tr>
#       <th id="T_34baf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_34baf_row8_col0" class="data row8 col0" >0.8667</td>
#       <td id="T_34baf_row8_col1" class="data row8 col1" >0.9800</td>
#       <td id="T_34baf_row8_col2" class="data row8 col2" >0.8000</td>
#       <td id="T_34baf_row8_col3" class="data row8 col3" >0.8000</td>
#       <td id="T_34baf_row8_col4" class="data row8 col4" >0.8000</td>
#       <td id="T_34baf_row8_col5" class="data row8 col5" >0.7000</td>
#       <td id="T_34baf_row8_col6" class="data row8 col6" >0.7000</td>
#     </tr>
#     <tr>
#       <th id="T_34baf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_34baf_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_34baf_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_34baf_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_34baf_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_34baf_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_34baf_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_34baf_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_34baf_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_34baf_row10_col0" class="data row10 col0" >0.9738</td>
#       <td id="T_34baf_row10_col1" class="data row10 col1" >0.9980</td>
#       <td id="T_34baf_row10_col2" class="data row10 col2" >0.9633</td>
#       <td id="T_34baf_row10_col3" class="data row10 col3" >0.9633</td>
#       <td id="T_34baf_row10_col4" class="data row10 col4" >0.9618</td>
#       <td id="T_34baf_row10_col5" class="data row10 col5" >0.9419</td>
#       <td id="T_34baf_row10_col6" class="data row10 col6" >0.9436</td>
#     </tr>
#     <tr>
#       <th id="T_34baf_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_34baf_row11_col0" class="data row11 col0" >0.0439</td>
#       <td id="T_34baf_row11_col1" class="data row11 col1" >0.0060</td>
#       <td id="T_34baf_row11_col2" class="data row11 col2" >0.0737</td>
#       <td id="T_34baf_row11_col3" class="data row11 col3" >0.0737</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
#tuned model object is stored in the variable 'tuned_rf'. 
tuned_rf
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=123, verbose=0, warm_start=False)

# %% [markdown]
# **Evaluate Decision Tree Model**

# %%
#Update statmodels
#!pip3 install statsmodels --upgrade

# %% [markdown]
# How to analyze model performance using various plots

# %%
evaluate_model(tuned_rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# **Create Extra Tree Classifier Model**

# %%
et = create_model('et')
# Out:
# <style type="text/css">
# #T_03394_row10_col0, #T_03394_row10_col1, #T_03394_row10_col2, #T_03394_row10_col3, #T_03394_row10_col4, #T_03394_row10_col5, #T_03394_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_03394" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03394_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_03394_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_03394_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_03394_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_03394_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_03394_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_03394_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03394_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03394_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_03394_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_03394_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_03394_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_03394_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_03394_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_03394_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_03394_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_03394_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_03394_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_03394_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_03394_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_03394_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_03394_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_03394_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_03394_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_03394_row2_col0" class="data row2 col0" >0.9375</td>
#       <td id="T_03394_row2_col1" class="data row2 col1" >0.9833</td>
#       <td id="T_03394_row2_col2" class="data row2 col2" >0.8333</td>
#       <td id="T_03394_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_03394_row2_col4" class="data row2 col4" >0.9091</td>
#       <td id="T_03394_row2_col5" class="data row2 col5" >0.8621</td>
#       <td id="T_03394_row2_col6" class="data row2 col6" >0.8704</td>
#     </tr>
#     <tr>
#       <th id="T_03394_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_03394_row3_col0" class="data row3 col0" >0.9375</td>
#       <td id="T_03394_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_03394_row3_col2" class="data row3 col2" >0.8333</td>
#       <td id="T_03394_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_03394_row3_col4" class="data row3 col4" >0.9091</td>
#       <td id="T_03394_row3_col5" class="data row3 col5" >0.8621</td>
#       <td id="T_03394_row3_col6" class="data row3 col6" >0.8704</td>
#     </tr>
#     <tr>
#       <th id="T_03394_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_03394_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_03394_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_03394_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_03394_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_03394_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_03394_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_03394_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_03394_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_03394_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_03394_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_03394_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_03394_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_03394_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_03394_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_03394_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_03394_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_03394_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_03394_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_03394_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_03394_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_03394_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_03394_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_03394_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_03394_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_03394_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_03394_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_03394_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_03394_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_03394_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_03394_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_03394_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_03394_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_03394_row8_col0" class="data row8 col0" >0.8667</td>
#       <td id="T_03394_row8_col1" class="data row8 col1" >0.9800</td>
#       <td id="T_03394_row8_col2" class="data row8 col2" >0.8000</td>
#       <td id="T_03394_row8_col3" class="data row8 col3" >0.8000</td>
#       <td id="T_03394_row8_col4" class="data row8 col4" >0.8000</td>
#       <td id="T_03394_row8_col5" class="data row8 col5" >0.7000</td>
#       <td id="T_03394_row8_col6" class="data row8 col6" >0.7000</td>
#     </tr>
#     <tr>
#       <th id="T_03394_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_03394_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_03394_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_03394_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_03394_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_03394_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_03394_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_03394_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_03394_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_03394_row10_col0" class="data row10 col0" >0.9742</td>
#       <td id="T_03394_row10_col1" class="data row10 col1" >0.9963</td>
#       <td id="T_03394_row10_col2" class="data row10 col2" >0.9467</td>
#       <td id="T_03394_row10_col3" class="data row10 col3" >0.9800</td>
#       <td id="T_03394_row10_col4" class="data row10 col4" >0.9618</td>
#       <td id="T_03394_row10_col5" class="data row10 col5" >0.9424</td>
#       <td id="T_03394_row10_col6" class="data row10 col6" >0.9441</td>
#     </tr>
#     <tr>
#       <th id="T_03394_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_03394_row11_col0" class="data row11 col0" >0.0435</td>
#       <td id="T_03394_row11_col1" class="data row11 col1" >0.0074</td>
#       <td id="T_03394_row11_col2" class="data row11 col2" >0.0819</td>
#       <td id="T_03394_row11_col3" class="data row11 col3" >0.0600</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# **Tune Extra Tree Classifier Model**

# %%
tuned_et = tune_model(et)
# Out:
# <style type="text/css">
# #T_61f06_row10_col0, #T_61f06_row10_col1, #T_61f06_row10_col2, #T_61f06_row10_col3, #T_61f06_row10_col4, #T_61f06_row10_col5, #T_61f06_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_61f06" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61f06_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_61f06_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_61f06_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_61f06_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_61f06_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_61f06_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_61f06_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61f06_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61f06_row0_col0" class="data row0 col0" >0.9375</td>
#       <td id="T_61f06_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_61f06_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_61f06_row0_col3" class="data row0 col3" >0.8571</td>
#       <td id="T_61f06_row0_col4" class="data row0 col4" >0.9231</td>
#       <td id="T_61f06_row0_col5" class="data row0 col5" >0.8710</td>
#       <td id="T_61f06_row0_col6" class="data row0 col6" >0.8783</td>
#     </tr>
#     <tr>
#       <th id="T_
d7_row13_col0, #T_1d9d7_row13_col1, #T_1d9d7_row13_col2, #T_1d9d7_row13_col3, #T_1d9d7_row13_col4, #T_1d9d7_row13_col5, #T_1d9d7_row13_col6, #T_1d9d7_row13_col7, #T_1d9d7_row14_col0, #T_1d9d7_row14_col1, #T_1d9d7_row14_col2, #T_1d9d7_row14_col3, #T_1d9d7_row14_col4, #T_1d9d7_row14_col5, #T_1d9d7_row14_col6, #T_1d9d7_row14_col7 {
#   text-align: left;
# }
# #T_1d9d7_row0_col1, #T_1d9d7_row0_col4, #T_1d9d7_row0_col5, #T_1d9d7_row0_col6, #T_1d9d7_row0_col7, #T_1d9d7_row1_col3, #T_1d9d7_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1d9d7_row0_col8, #T_1d9d7_row1_col8, #T_1d9d7_row2_col8, #T_1d9d7_row4_col8, #T_1d9d7_row5_col8, #T_1d9d7_row6_col8, #T_1d9d7_row7_col8, #T_1d9d7_row8_col8, #T_1d9d7_row9_col8, #T_1d9d7_row11_col8, #T_1d9d7_row12_col8, #T_1d9d7_row13_col8, #T_1d9d7_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1d9d7_row3_col8, #T_1d9d7_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1d9d7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d9d7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1d9d7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1d9d7_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1d9d7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1d9d7_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1d9d7_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1d9d7_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1d9d7_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_1d9d7_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d9d7_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_1d9d7_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_1d9d7_row0_col1" class="data row0 col1" >0.9654</td>
#       <td id="T_1d9d7_row0_col2" class="data row0 col2" >0.9939</td>
#       <td id="T_1d9d7_row0_col3" class="data row0 col3" >0.9214</td>
#       <td id="T_1d9d7_row0_col4" class="data row0 col4" >0.9875</td>
#       <td id="T_1d9d7_row0_col5" class="data row0 col5" >0.9507</td>
#       <td id="T_1d9d7_row0_col6" class="data row0 col6" >0.9240</td>
#       <td id="T_1d9d7_row0_col7" class="data row0 col7" >0.9283</td>
#       <td id="T_1d9d7_row0_col8" class="data row0 col8" >0.3710</td>
#     </tr>
#     <tr>
#       <th id="T_1d9d7_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_1d9d7_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_1d9d7_row1_col1" class="data row1 col1" >0.9601</td>
#       <td id="T_1d9d7_row1_col2" class="data row1 col2" >0.9821</td>
#       <td id="T_1d9d7_row1_col3" class="data row1 col3" >0.9500</td>
#       <td id="T_1d9d7_row1_col4" class="data row1 col4" >0.9575</td>
#       <td id="T_1d9d7_row1_col5" class="data row1 col5" >0.9484</td>
#       <td id="T_1d9d7_row1_col6" class="data row1 col6" >0.9159</td>
#       <td id="T_1d9d7_row1_col7" class="data row1 col7" >0.9227</td>
#       <td id="T_1d9d7_row1_col8" class="data row1 col8" >0.1240</td>
#     </tr>
#     <tr>
#       <th id="T_1d9d7_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_1d9d7_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1d9d7_row2_col1" class="data row2 col1" >0.9595</td>
#       <td id="T_1d9d7_row2_col2" class="data row2 col2" >0.9972</td>
#       <td id="T_1d9d7_row2_col3" class="data row2 col3" >0.9357</td>
#       <td id="T_1d9d7_row2_col4" class="data row2 col4" >0.9583</td>
#       <td id="T_1d9d7_row2_col5" class="data row2 col5" >0.9441</td>
#       <td id="T_1d9d7_row2_col6" class="data row2 col6" >0.9123</td>
#       <td id="T_1d9d7_row2_col7" class="data row2 col7" >0.9157</td>
#       <td id="T_1d9d7_row2_col8" class="data row2 col8" >0.3790</td>
#     </tr>
#     <tr>
#       <th id="T_1d9d7_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T
row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_f2d1d_row4_col4" class="data row4 col4" >0.9231</td>
#       <td id="T_f2d1d_row4_col5" class="data row4 col5" >0.8759</td>
#       <td id="T_f2d1d_row4_col6" class="data row4 col6" >0.8827</td>
#     </tr>
#     <tr>
#       <th id="T_f2d1d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f2d1d_row5_col0" class="data row5 col0" >0.9412</td>
#       <td id="T_f2d1d_row5_col1" class="data row5 col1" >0.9848</td>
#       <td id="T_f2d1d_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_f2d1d_row5_col3" class="data row5 col3" >0.8571</td>
#       <td id="T_f2d1d_row5_col4" class="data row5 col4" >0.9231</td>
#       <td id="T_f2d1d_row5_col5" class="data row5 col5" >0.8759</td>
#       <td id="T_f2d1d_row5_col6" class="data row5 col6" >0.8827</td>
#     </tr>
#     <tr>
#       <th id="T_f2d1d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f2d1d_row6_col0" class="data row6 col0" >0.9412</td>
#       <td id="T_f2d1d_row6_col1" class="data row6 col1" >0.9848</td>
#       <td id="T_f2d1d_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_f2d1d_row6_col3" class="data row6 col3" >0.8571</td>
#       <td id="T_f2d1d_row6_col4" class="data row6 col4" >0.9231</td>
#       <td id="T_f2d1d_row6_col5" class="data row6 col5" >0.8759</td>
#       <td id="T_f2d1d_row6_col6" class="data row6 col6" >0.8827</td>
#     </tr>
#     <tr>
#       <th id="T_f2d1d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f2d1d_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_f2d1d_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_f2d1d_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_f2d1d_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_f2d1d_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_f2d1d_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_f2d1d_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2d1d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f2d1d_row8_col0" class="data row8 col0" >0.9412</td>
#       <td id="T_f2d1d_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_f2d1d_row8_col2" class="data row8 col2" >0.8333</td>
#       <td id="T_f2d1d_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_f2d1d_row8_col4" class="data row8 col4" >0.9091</td>
#       <td id="T_f2d1d_row8_col5" class="data row8 col5" >0.8661</td>
#       <td id="T_f2d1d_row8_col6" class="data row8 col6" >0.8740</td>
#     </tr>
#     <tr>
#       <th id="T_f2d1d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f2d1d_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_f2d1d_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_f2d1d_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_f2d1d_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_f2d1d_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_f2d1d_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_f2d1d_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2d1d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f2d1d_row10_col0" class="data row10 col0" >0.9654</td>
#       <td id="T_f2d1d_row10_col1" class="data row10 col1" >0.9970</td>
#       <td id="T_f2d1d_row10_col2" class="data row10 col2" >0.9690</td>
#       <td id="T_f2d1d_row10_col3" class="data row10 col3" >0.9464</td>
#       <td id="T_f2d1d_row10_col4" class="data row10 col4" >0.9545</td>
#       <td id="T_f2d1d_row10_col5" class="data row10 col5" >0.9266</td>
#       <td id="T_f2d1d_row10_col6" class="data row10 col6" >0.9306</td>
#     </tr>
#     <tr>
#       <th id="T_f2d1d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f2d1d_row11_col0" class="data row11 col0" >0.0283</td>
#       <td id="T_f2d1d_row11_col1" class="data row11 col1" >0.0061</td>
#       <td id="T_f2d1d_row11_col2" class="data row11 col2" >0.0621</td>
#       <td id="T_f2d1d_row11_col3" class="data row11 col3" >0.0659</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
tuned_best_model_pca
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='sqrt',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_samples_leaf=1,
#                      min_samples_split=2, min_weight_fraction_leaf=0.0,
#                      n_estimators=100, n_jobs=-1, oob_score=False,
#                      random_state=123, verbose=0, warm_start=False)

# %% [markdown]
# **Evaluate the Best Model**
#
# One way to analyze the performance of models is to use the evaluate_model() function which displays a user interface for all of the available plots for a given model. It internally uses the plot_model() function.

# %%
evaluate_model(tuned_best_model_pca)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# **Note:** The AUC metric is not available for Multiclass classification however the column will still be shown with zero values to maintain consistency between the Binary Classification and Multiclass Classification display grids.

# %% [markdown]
# #**Explainable AI with Shapley values**
#
# Shapley values are a widely used approach from cooperative game theory that come with desirable properties.
#
# SHAP is a Python library for model interpretation and feature importance analysis, and it provides a variety of tools for explaining the output of machine learning models. The library is based on the Shapley value, a concept from cooperative game theory that assigns a value to each player in a game based on their contribution to the overall outcome.

# %%
# !pip3 install shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.41.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.65.0)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.10.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.22.4)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->shap) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)

# %%
#import the SHAP (SHapley Additive exPlanations) library
import shap

# %%
rf_pca = create_model('rf')
# Out:
# <style type="text/css">
# #T_f99d4_row10_col0, #T_f99d4_row10_col1, #T_f99d4_row10_col2, #T_f99d4_row10_col3, #T_f99d4_row10_col4, #T_f99d4_row10_col5, #T_f99d4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_
row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_22b67_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_22b67_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_22b67_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_22b67_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_22b67_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_22b67_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_22b67_row8_col0" class="data row8 col0" >0.9412</td>
#       <td id="T_22b67_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_22b67_row8_col2" class="data row8 col2" >0.8333</td>
#       <td id="T_22b67_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_22b67_row8_col4" class="data row8 col4" >0.9091</td>
#       <td id="T_22b67_row8_col5" class="data row8 col5" >0.8661</td>
#       <td id="T_22b67_row8_col6" class="data row8 col6" >0.8740</td>
#     </tr>
#     <tr>
#       <th id="T_22b67_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_22b67_row9_col0" class="data row9 col0" >0.9412</td>
#       <td id="T_22b67_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_22b67_row9_col2" class="data row9 col2" >0.8333</td>
#       <td id="T_22b67_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_22b67_row9_col4" class="data row9 col4" >0.9091</td>
#       <td id="T_22b67_row9_col5" class="data row9 col5" >0.8661</td>
#       <td id="T_22b67_row9_col6" class="data row9 col6" >0.8740</td>
#     </tr>
#     <tr>
#       <th id="T_22b67_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_22b67_row10_col0" class="data row10 col0" >0.9595</td>
#       <td id="T_22b67_row10_col1" class="data row10 col1" >0.9956</td>
#       <td id="T_22b67_row10_col2" class="data row10 col2" >0.8905</td>
#       <td id="T_22b67_row10_col3" class="data row10 col3" >1.0000</td>
#       <td id="T_22b67_row10_col4" class="data row10 col4" >0.9406</td>
#       <td id="T_22b67_row10_col5" class="data row10 col5" >0.9100</td>
#       <td id="T_22b67_row10_col6" class="data row10 col6" >0.9152</td>
#     </tr>
#     <tr>
#       <th id="T_22b67_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_22b67_row11_col0" class="data row11 col0" >0.0266</td>
#       <td id="T_22b67_row11_col1" class="data row11 col1" >0.0060</td>
#       <td id="T_22b67_row11_col2" class="data row11 col2" >0.0724</td>
#       <td id="T_22b67_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %% [markdown]
# **SHAP Summary Plot**
#
# Rather than using a typical feature importance bar chart, we use a density scatter plot of SHAP values for each feature to identify how much impact each feature has on the model output for individuals in the validation dataset. Features are sorted by the sum of the SHAP value magnitudes across all samples.

# %%
interpret_model(tuned_rf_pca, plot='summary')

# %%
#explainer = shap.TreeExplainer(tuned_rf_pca)
#X = df.drop('class', axis=1)
#shap_values = explainer.shap_values(X)
#shap.summary_plot(shap_values, X)

# %% [markdown]
# **Visualize a single prediction**

# %%
interpret_model(tuned_rf_pca, plot='reason', observation=32)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='i1B1JOVQBHQSF4B2UROUH'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.37360426929392454, "outValue": 0.264729336458904, "link": "identity", "featureNames": ["pca0", "pca1", "pca2"], "features": {"0": {"effect": -0.10887493283502053, "value": -0.1175660714507103}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i1B1JOVQBHQSF4B2UROUH')
#   );
# </script>

# %% [markdown]
# From the above the plot, we can seethe "base value," which is defined as the mean predicted target; and f(x), which is the prediction for a selected observation (i.e. observation number 32). The red-colored features increased the predicted value, while the blue-colored features decreased it. The size of each feature (i.e. Principal Component) indicates the impact it has on the model.

# %% [markdown]
# **Visualize many predictions**

# %%
interpret_model(tuned_rf_pca, plot='reason')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='i5R577GN7YT0XHSH8XFB0'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.37360426929392454, "link": "identity", "featureNames": ["pca0", "pca1", "pca2"], "explanations": [{"outValue": 0.264729336458904, "simIndex": 54.0, "features": {"0": {"effect": -0.10887493283502053, "value": -1.4730224609375}, "1": {"effect": 0.0, "value": -0.15707355737686157}, "2": {"effect": 0.0, "value": -0.2678454518318176}}}, {"outValue": 0.4910536668431205, "simIndex": 26.0, "features": {"0": {"effect": 0.11744939754919599, "value": 0.8237128853797913}, "1": {"effect": 0.0, "value": -0.4521842300891876}, "2": {"effect": 0.0, "value": 0.5544306039810181}}}, {"outValue": 0.5528818879215706, "simIndex": 12.0, "features": {"0": {"effect": 0.17927761862764602, "value": 2.419612407684326}, "1": {"effect": 0.0, "value": -0.6949658989906311}, "2": {"effect": 0.0, "value": -0.16538205742835999}}}, {"outValue": 0.264729336458904, "simIndex":